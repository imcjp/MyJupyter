# %%
from IPython.display import display, HTML

# 读取HTML文件内容
path='D:/GitHub/MyJupyter/htmls/test.htm'
with open(path, 'r', encoding='utf-8') as f:
    html_content = f.read()

# 在Jupyter Notebook中显示HTML内容
display(HTML(html_content))
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>MNIST下，使用WRes各个不同的DPCR模型的不同迭代次数对于学习效果的影响（精度）</title>
#                 <script type="text/javascript" src="https://assets.pyecharts.org/assets/v5/echarts.min.js"></script>
#
# </head>
# <body >
#     <div id="b8e2581c7d1f4c4f81ca2142c694e695" class="chart-container" style="width:800px; height:640px; "></div>
#     <script>
#         var chart_b8e2581c7d1f4c4f81ca2142c694e695 = echarts.init(
#             document.getElementById('b8e2581c7d1f4c4f81ca2142c694e695'), 'white', {renderer: 'canvas'});
#         var option_b8e2581c7d1f4c4f81ca2142c694e695 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "SimpleMech",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     1000,
#                     0.572
#                 ],
#                 [
#                     2000,
#                     0.5879
#                 ],
#                 [
#                     5000,
#                     0.6591
#                 ],
#                 [
#                     10000,
#                     0.8044333333333333
#                 ],
#                 [
#                     20000,
#                     0.8782
#                 ],
#                 [
#                     50000,
#                     0.8763
#                 ],
#                 [
#                     100000,
#                     0.7770333333333332
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "TwoLevel",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     1000,
#                     0.6007333333333333
#                 ],
#                 [
#                     2000,
#                     0.5819
#                 ],
#                 [
#                     5000,
#                     0.6787666666666667
#                 ],
#                 [
#                     10000,
#                     0.7335666666666666
#                 ],
#                 [
#                     20000,
#                     0.8079999999999999
#                 ],
#                 [
#                     50000,
#                     0.8766666666666666
#                 ],
#                 [
#                     100000,
#                     0.9048333333333334
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "BinMech",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     1000,
#                     0.5075666666666667
#                 ],
#                 [
#                     2000,
#                     0.4817666666666666
#                 ],
#                 [
#                     5000,
#                     0.48593333333333333
#                 ],
#                 [
#                     10000,
#                     0.4237333333333333
#                 ],
#                 [
#                     20000,
#                     0.2719
#                 ],
#                 [
#                     50000,
#                     0.14323333333333335
#                 ],
#                 [
#                     100000,
#                     0.1084
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "Honaker",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     1000,
#                     0.6548333333333334
#                 ],
#                 [
#                     2000,
#                     0.7353333333333333
#                 ],
#                 [
#                     5000,
#                     0.7577333333333334
#                 ],
#                 [
#                     10000,
#                     0.8106
#                 ],
#                 [
#                     20000,
#                     0.8200666666666666
#                 ],
#                 [
#                     50000,
#                     0.7209
#                 ],
#                 [
#                     100000,
#                     0.5890333333333334
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "FDA",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     1000,
#                     0.23183333333333334
#                 ],
#                 [
#                     2000,
#                     0.21893333333333334
#                 ],
#                 [
#                     5000,
#                     0.13586666666666666
#                 ],
#                 [
#                     10000,
#                     0.10473333333333333
#                 ],
#                 [
#                     20000,
#                     0.10216666666666667

# %%
from IPython.display import IFrame

# 指定网页URL并设置宽度和高度
url = "D:\\GitHub\\MyJupyter\\htmls\\test.htm"
width = 800
height = 600

# 在Jupyter Notebook中展示网页
display(IFrame(url, width=width, height=height))
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="D:\GitHub\MyJupyter\htmls\test.htm"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
